# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 788

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description =city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | concepcion
# Processing Record 3 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | bushehr
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | bocaranga
# City not found. Skipping...
# Processing Record 12 of Set 1 | omsukchan
# Processing Record 13 of Set 1 | skibbereen
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | meulaboh
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | alekseyevka
# Processing Record 18 of Set 1 | catuday
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | saint-gedeon
# Processing Record 23 of Set 1 | bobo dioulasso
# Processing Record 24 of Set 1 | ilhabela
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | devonport
# Processing Record 28 of Set 1 | kloulklubed
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | arona
# Processing Record 34 of Set 1 | yatou
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | aksu
# Processing Record 37 of Set 1 | atar
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | pandharpur
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | khash
# Processing Record 43 of Set 1 | paka
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | pauini
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | buala
# Processing Record 2 of Set 2 | axim
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | kungurtug
# Processing Record 5 of Set 2 | oktyabrskiy
# Processing Record 6 of Set 2 | san jose
# Processing Record 7 of Set 2 | zhigansk
# Processing Record 8 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | kahama
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | fairbanks
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | tocopilla
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | novobiryusinskiy
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | panubigan
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | zhezkazgan
# Processing Record 22 of Set 2 | genhe
# Processing Record 23 of Set 2 | emba
# Processing Record 24 of Set 2 | khairpur nathan shah
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | hervey bay
# Processing Record 30 of Set 2 | carbonia
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | inuvik
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | louth
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | ternate
# Processing Record 37 of Set 2 | mugumu
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | pemba
# Processing Record 40 of Set 2 | carutapera
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | zhuanghe
# Processing Record 43 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 44 of Set 2 | booue
# Processing Record 45 of Set 2 | bull savanna
# Processing Record 46 of Set 2 | vila franca do campo
# Processing Record 47 of Set 2 | luderitz
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | barcelos
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | ibia
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | hami
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | sambava
# Processing Record 6 of Set 3 | santa maria
# Processing Record 7 of Set 3 | basesti
# Processing Record 8 of Set 3 | labuhan
# Processing Record 9 of Set 3 | natalinsk
# Processing Record 10 of Set 3 | baykit
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | sao felix do xingu
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | burica
# City not found. Skipping...
# Processing Record 17 of Set 3 | san pedro
# Processing Record 18 of Set 3 | novita
# Processing Record 19 of Set 3 | sorland
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | san carlos de bariloche
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | simao
# Processing Record 25 of Set 3 | jiuquan
# Processing Record 26 of Set 3 | talnakh
# Processing Record 27 of Set 3 | umea
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | mangai
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | sao jose da coroa grande
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | tevaitoa
# Processing Record 37 of Set 3 | brooks
# Processing Record 38 of Set 3 | umm kaddadah
# Processing Record 39 of Set 3 | pabellon de hidalgo
# Processing Record 40 of Set 3 | gweta
# Processing Record 41 of Set 3 | dwarka
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | hermanus
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | salinopolis
# Processing Record 47 of Set 3 | aguimes
# Processing Record 48 of Set 3 | kamiiso
# Processing Record 49 of Set 3 | birao
# Processing Record 50 of Set 3 | takoradi
# Processing Record 1 of Set 4 | chantada
# Processing Record 2 of Set 4 | sao joao da barra
# Processing Record 3 of Set 4 | lafiagi
# Processing Record 4 of Set 4 | alofi
# Processing Record 5 of Set 4 | avera
# Processing Record 6 of Set 4 | davidson
# Processing Record 7 of Set 4 | ayotzintepec
# Processing Record 8 of Set 4 | sisimiut
# Processing Record 9 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | kapit
# Processing Record 11 of Set 4 | chancay
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | peredovaya
# Processing Record 15 of Set 4 | lakselv
# Processing Record 16 of Set 4 | olinda
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 4 | bonavista
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | vostok
# Processing Record 23 of Set 4 | kudahuvadhoo
# Processing Record 24 of Set 4 | roma
# Processing Record 25 of Set 4 | baft
# Processing Record 26 of Set 4 | acapulco
# Processing Record 27 of Set 4 | bilibino
# Processing Record 28 of Set 4 | werneck
# Processing Record 29 of Set 4 | banda aceh
# Processing Record 30 of Set 4 | tangshan
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | oktyabrskoye
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | pundaguitan
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 4 | copiapo
# Processing Record 39 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 4 | balkanabat
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | sainte-anne-des-monts
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | airai
# Processing Record 45 of Set 4 | kulhudhuffushi
# Processing Record 46 of Set 4 | naze
# Processing Record 47 of Set 4 | hukuntsi
# Processing Record 48 of Set 4 | chabahar
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | rucheng
# Processing Record 2 of Set 5 | akureyri
# Processing Record 3 of Set 5 | abaete
# Processing Record 4 of Set 5 | konevo
# Processing Record 5 of Set 5 | gizo
# Processing Record 6 of Set 5 | ibadan
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | north bend
# Processing Record 10 of Set 5 | hvide sande
# Processing Record 11 of Set 5 | maymanak
# City not found. Skipping...
# Processing Record 12 of Set 5 | palestina
# Processing Record 13 of Set 5 | coihaique
# Processing Record 14 of Set 5 | vannes
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | vestmanna
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | biltine
# Processing Record 21 of Set 5 | westport
# Processing Record 22 of Set 5 | mujiayingzi
# Processing Record 23 of Set 5 | srednekolymsk
# Processing Record 24 of Set 5 | havre
# Processing Record 25 of Set 5 | huangmei
# Processing Record 26 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 5 | kasongo-lunda
# Processing Record 28 of Set 5 | auburn
# Processing Record 29 of Set 5 | bonthe
# Processing Record 30 of Set 5 | anori
# Processing Record 31 of Set 5 | stepnoye
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | krasnoselkup
# Processing Record 34 of Set 5 | george
# Processing Record 35 of Set 5 | malindi
# Processing Record 36 of Set 5 | quepos
# Processing Record 37 of Set 5 | puerto escondido
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | alba
# Processing Record 40 of Set 5 | korogwe
# City not found. Skipping...
# Processing Record 41 of Set 5 | batagay-alyta
# Processing Record 42 of Set 5 | esso
# Processing Record 43 of Set 5 | kavaratti
# Processing Record 44 of Set 5 | mahebourg
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | broome
# Processing Record 47 of Set 5 | mount isa
# Processing Record 48 of Set 5 | bubaque
# Processing Record 49 of Set 5 | grootfontein
# Processing Record 50 of Set 5 | belyy yar
# Processing Record 1 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 6 | vrangel
# Processing Record 3 of Set 6 | saldanha
# Processing Record 4 of Set 6 | humaita
# Processing Record 5 of Set 6 | lazaro cardenas
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | staryy biser
# City not found. Skipping...
# Processing Record 9 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 6 | bilma
# Processing Record 11 of Set 6 | havre-saint-pierre
# Processing Record 12 of Set 6 | ligayan
# Processing Record 13 of Set 6 | port elizabeth
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | maniitsoq
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | chernyshevskiy
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | kailua
# Processing Record 21 of Set 6 | lincoln
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | verkhnyaya toyma
# Processing Record 24 of Set 6 | roebourne
# Processing Record 25 of Set 6 | valparaiso
# Processing Record 26 of Set 6 | videbaek
# Processing Record 27 of Set 6 | puerto narino
# Processing Record 28 of Set 6 | limbe
# Processing Record 29 of Set 6 | ariquemes
# Processing Record 30 of Set 6 | viedma
# Processing Record 31 of Set 6 | daugai
# Processing Record 32 of Set 6 | mandera
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | brookhaven
# Processing Record 35 of Set 6 | makhalino
# Processing Record 36 of Set 6 | chegdomyn
# Processing Record 37 of Set 6 | wattegama
# Processing Record 38 of Set 6 | necochea
# Processing Record 39 of Set 6 | pechenga
# Processing Record 40 of Set 6 | high prairie
# Processing Record 41 of Set 6 | zeya
# Processing Record 42 of Set 6 | fort nelson
# Processing Record 43 of Set 6 | nadvoitsy
# Processing Record 44 of Set 6 | khvastovichi
# Processing Record 45 of Set 6 | qui nhon
# Processing Record 46 of Set 6 | zemio
# Processing Record 47 of Set 6 | los llanos de aridane
# Processing Record 48 of Set 6 | belaya gora
# Processing Record 49 of Set 6 | mount darwin
# Processing Record 50 of Set 6 | umrala
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | nyagan
# Processing Record 3 of Set 7 | sol-iletsk
# Processing Record 4 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 7 | morondava
# Processing Record 6 of Set 7 | san quintin
# Processing Record 7 of Set 7 | anekal
# Processing Record 8 of Set 7 | vila nova de milfontes
# Processing Record 9 of Set 7 | juba
# Processing Record 10 of Set 7 | barrow
# Processing Record 11 of Set 7 | panaba
# Processing Record 12 of Set 7 | udachnyy
# Processing Record 13 of Set 7 | abnub
# Processing Record 14 of Set 7 | bandarbeyla
# Processing Record 15 of Set 7 | cap-aux-meules
# Processing Record 16 of Set 7 | puerto del rosario
# Processing Record 17 of Set 7 | rawson
# Processing Record 18 of Set 7 | odienne
# Processing Record 19 of Set 7 | capinopolis
# Processing Record 20 of Set 7 | mama
# Processing Record 21 of Set 7 | stromness
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | bereznik
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | asfi
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | hay river
# Processing Record 30 of Set 7 | dali
# Processing Record 31 of Set 7 | numan
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | chuy
# Processing Record 34 of Set 7 | saskylakh
# Processing Record 35 of Set 7 | mandalgovi
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | oranjemund
# Processing Record 38 of Set 7 | chokurdakh
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | shipitsyno
# Processing Record 41 of Set 7 | boguchany
# Processing Record 42 of Set 7 | guatire
# Processing Record 43 of Set 7 | karratha
# Processing Record 44 of Set 7 | rorvik
# Processing Record 45 of Set 7 | najran
# Processing Record 46 of Set 7 | kimberley
# Processing Record 47 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | tete
# Processing Record 50 of Set 7 | saint george
# Processing Record 1 of Set 8 | opuwo
# Processing Record 2 of Set 8 | gariaband
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | kushima
# Processing Record 5 of Set 8 | churapcha
# Processing Record 6 of Set 8 | rio gallegos
# Processing Record 7 of Set 8 | belmonte
# Processing Record 8 of Set 8 | olutanga
# Processing Record 9 of Set 8 | kichmengskiy gorodok
# Processing Record 10 of Set 8 | waipawa
# Processing Record 11 of Set 8 | puerto madryn
# Processing Record 12 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 8 | ambunti
# Processing Record 14 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 8 | santa isabel
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | batticaloa
# Processing Record 18 of Set 8 | dambulla
# Processing Record 19 of Set 8 | evensk
# Processing Record 20 of Set 8 | caconda
# Processing Record 21 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 8 | bintulu
# Processing Record 23 of Set 8 | bathsheba
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | camocim
# Processing Record 28 of Set 8 | shamary
# Processing Record 29 of Set 8 | ayan
# Processing Record 30 of Set 8 | fukue
# Processing Record 31 of Set 8 | korla
# Processing Record 32 of Set 8 | skjervoy
# Processing Record 33 of Set 8 | guayape
# Processing Record 34 of Set 8 | mankato
# Processing Record 35 of Set 8 | whitehorse
# Processing Record 36 of Set 8 | ostrovnoy
# Processing Record 37 of Set 8 | centerville
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | carupano
# Processing Record 40 of Set 8 | mtambile
# Processing Record 41 of Set 8 | nsanje
# Processing Record 42 of Set 8 | deseronto
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | san policarpo
# Processing Record 45 of Set 8 | lively
# Processing Record 46 of Set 8 | fort abbas
# Processing Record 47 of Set 8 | wewak
# Processing Record 48 of Set 8 | kolpny
# Processing Record 49 of Set 8 | kidal
# Processing Record 50 of Set 8 | ponta do sol
# Processing Record 1 of Set 9 | gornopravdinsk
# Processing Record 2 of Set 9 | kayerkan
# Processing Record 3 of Set 9 | kwidzyn
# Processing Record 4 of Set 9 | omagh
# Processing Record 5 of Set 9 | la libertad
# Processing Record 6 of Set 9 | charters towers
# Processing Record 7 of Set 9 | isiro
# Processing Record 8 of Set 9 | arman
# Processing Record 9 of Set 9 | natal
# Processing Record 10 of Set 9 | maumere
# Processing Record 11 of Set 9 | stepnyak
# Processing Record 12 of Set 9 | polyarnyy
# Processing Record 13 of Set 9 | pangnirtung
# Processing Record 14 of Set 9 | gornyy
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | el alto
# Processing Record 17 of Set 9 | green river
# Processing Record 18 of Set 9 | kangaatsiaq
# Processing Record 19 of Set 9 | qaqortoq
# Processing Record 20 of Set 9 | batagay
# Processing Record 21 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 9 | sur
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | acarau
# Processing Record 25 of Set 9 | kankon
# Processing Record 26 of Set 9 | tsaratanana
# Processing Record 27 of Set 9 | ugoofaaru
# Processing Record 28 of Set 9 | baghdad
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | tansen
# Processing Record 31 of Set 9 | saint-pierre
# Processing Record 32 of Set 9 | kavieng
# Processing Record 33 of Set 9 | mineros
# Processing Record 34 of Set 9 | barra do garcas
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | west wendover
# Processing Record 37 of Set 9 | ginir
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | ishigaki
# Processing Record 40 of Set 9 | leshukonskoye
# Processing Record 41 of Set 9 | mnogovershinnyy
# Processing Record 42 of Set 9 | saint-georges
# Processing Record 43 of Set 9 | nichinan
# Processing Record 44 of Set 9 | tondano
# Processing Record 45 of Set 9 | ketchikan
# Processing Record 46 of Set 9 | ilek
# Processing Record 47 of Set 9 | maceio
# Processing Record 48 of Set 9 | sinnamary
# Processing Record 49 of Set 9 | mount gambier
# Processing Record 50 of Set 9 | maningrida
# Processing Record 1 of Set 10 | sakakah
# Processing Record 2 of Set 10 | pervomayskoye
# Processing Record 3 of Set 10 | prince rupert
# Processing Record 4 of Set 10 | roald
# Processing Record 5 of Set 10 | bograd
# Processing Record 6 of Set 10 | taloqan
# Processing Record 7 of Set 10 | beya
# Processing Record 8 of Set 10 | adrar
# Processing Record 9 of Set 10 | igarka
# Processing Record 10 of Set 10 | clayton
# Processing Record 11 of Set 10 | tambopata
# Processing Record 12 of Set 10 | pulsano
# Processing Record 13 of Set 10 | monrovia
# Processing Record 14 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 10 | yanam
# Processing Record 16 of Set 10 | ulladulla
# Processing Record 17 of Set 10 | klyuchi
# Processing Record 18 of Set 10 | port lincoln
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | zorgo
# Processing Record 21 of Set 10 | port alberni
# Processing Record 22 of Set 10 | nioro
# Processing Record 23 of Set 10 | iqaluit
# Processing Record 24 of Set 10 | kang
# Processing Record 25 of Set 10 | safita
# Processing Record 26 of Set 10 | jalu
# Processing Record 27 of Set 10 | yar-sale
# Processing Record 28 of Set 10 | lorengau
# Processing Record 29 of Set 10 | fengkou
# Processing Record 30 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 10 | oxapampa
# Processing Record 32 of Set 10 | owen sound
# Processing Record 33 of Set 10 | manhattan
# Processing Record 34 of Set 10 | vozhega
# Processing Record 35 of Set 10 | cortes
# Processing Record 36 of Set 10 | palembang
# Processing Record 37 of Set 10 | vila
# Processing Record 38 of Set 10 | port hedland
# Processing Record 39 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 40 of Set 10 | helong
# Processing Record 41 of Set 10 | esna
# Processing Record 42 of Set 10 | vanino
# Processing Record 43 of Set 10 | pasighat
# Processing Record 44 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | yeniseysk
# Processing Record 48 of Set 10 | consett
# Processing Record 49 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 10 | samatau
# City not found. Skipping...
# Processing Record 1 of Set 11 | lima
# Processing Record 2 of Set 11 | kieta
# Processing Record 3 of Set 11 | kiunga
# Processing Record 4 of Set 11 | nizwa
# Processing Record 5 of Set 11 | taltal
# Processing Record 6 of Set 11 | vanavara
# Processing Record 7 of Set 11 | helena
# Processing Record 8 of Set 11 | honiara
# Processing Record 9 of Set 11 | huanan
# Processing Record 10 of Set 11 | amahai
# Processing Record 11 of Set 11 | vredendal
# Processing Record 12 of Set 11 | trofors
# Processing Record 13 of Set 11 | dondo
# Processing Record 14 of Set 11 | gimli
# Processing Record 15 of Set 11 | bumba
# Processing Record 16 of Set 11 | knurow
# Processing Record 17 of Set 11 | caceres
# Processing Record 18 of Set 11 | williston
# Processing Record 19 of Set 11 | naryan-mar
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | pingyi
# Processing Record 22 of Set 11 | riachao do dantas
# Processing Record 23 of Set 11 | mehamn
# Processing Record 24 of Set 11 | chilca
# Processing Record 25 of Set 11 | christchurch
# Processing Record 26 of Set 11 | nyurba
# Processing Record 27 of Set 11 | tahe
# Processing Record 28 of Set 11 | yumen
# Processing Record 29 of Set 11 | ascension
# Processing Record 30 of Set 11 | la serena
# Processing Record 31 of Set 11 | penzance
# Processing Record 32 of Set 11 | fare
# Processing Record 33 of Set 11 | filadelfia
# Processing Record 34 of Set 11 | alhama de murcia
# Processing Record 35 of Set 11 | mokhsogollokh
# Processing Record 36 of Set 11 | xuddur
# Processing Record 37 of Set 11 | dickinson
# Processing Record 38 of Set 11 | wloclawek
# Processing Record 39 of Set 11 | barranca
# Processing Record 40 of Set 11 | kintampo
# Processing Record 41 of Set 11 | new glasgow
# Processing Record 42 of Set 11 | sayyan
# Processing Record 43 of Set 11 | bowen
# Processing Record 44 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | bitung
# Processing Record 46 of Set 11 | vila velha
# Processing Record 47 of Set 11 | mormugao
# Processing Record 48 of Set 11 | crystal beach
# Processing Record 49 of Set 11 | antalaha
# Processing Record 50 of Set 11 | lata
# Processing Record 1 of Set 12 | asau
# Processing Record 2 of Set 12 | westerly
# Processing Record 3 of Set 12 | brae
# Processing Record 4 of Set 12 | calvinia
# Processing Record 5 of Set 12 | bara
# Processing Record 6 of Set 12 | manokwari
# Processing Record 7 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 12 | muros
# Processing Record 9 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 12 | oistins
# Processing Record 11 of Set 12 | aksarka
# Processing Record 12 of Set 12 | souillac
# Processing Record 13 of Set 12 | siavonga
# Processing Record 14 of Set 12 | tromso
# Processing Record 15 of Set 12 | dese
# Processing Record 16 of Set 12 | saint anthony
# Processing Record 17 of Set 12 | ust-uda
# Processing Record 18 of Set 12 | aykhal
# Processing Record 19 of Set 12 | kununurra
# Processing Record 20 of Set 12 | sibu
# Processing Record 21 of Set 12 | chkalovskoye
# Processing Record 22 of Set 12 | goderich
# Processing Record 23 of Set 12 | bagh
# Processing Record 24 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 12 | banamba
# Processing Record 26 of Set 12 | mahajanga
# Processing Record 27 of Set 12 | novoasbest
# Processing Record 28 of Set 12 | koupela
# Processing Record 29 of Set 12 | vyshneve
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | mecca
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | te anau
# Processing Record 34 of Set 12 | berlevag
# Processing Record 35 of Set 12 | komatipoort
# Processing Record 36 of Set 12 | morro bay
# Processing Record 37 of Set 12 | okakarara
# Processing Record 38 of Set 12 | clyde river
# Processing Record 39 of Set 12 | horadiz
# Processing Record 40 of Set 12 | aasiaat
# Processing Record 41 of Set 12 | cerritos
# Processing Record 42 of Set 12 | muzhi
# Processing Record 43 of Set 12 | tautira
# Processing Record 44 of Set 12 | biggar
# Processing Record 45 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 12 | lucea
# Processing Record 47 of Set 12 | richards bay
# Processing Record 48 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 12 | musoma
# Processing Record 50 of Set 12 | juazeiro
# Processing Record 1 of Set 13 | gamba
# Processing Record 2 of Set 13 | ovalle
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | alappuzha
# Processing Record 5 of Set 13 | hobyo
# Processing Record 6 of Set 13 | jackson
# Processing Record 7 of Set 13 | vaitape
# Processing Record 8 of Set 13 | hayden
# Processing Record 9 of Set 13 | abu samrah
# Processing Record 10 of Set 13 | grand haven
# Processing Record 11 of Set 13 | santa cruz
# Processing Record 12 of Set 13 | chimbote
# Processing Record 13 of Set 13 | honningsvag
# Processing Record 14 of Set 13 | cayenne
# Processing Record 15 of Set 13 | anamur
# Processing Record 16 of Set 13 | orasac
# Processing Record 17 of Set 13 | kasongo
# Processing Record 18 of Set 13 | tessalit
# Processing Record 19 of Set 13 | marystown
# Processing Record 20 of Set 13 | hofn
# Processing Record 21 of Set 13 | changji
# Processing Record 22 of Set 13 | weligama
# Processing Record 23 of Set 13 | magdalena
# Processing Record 24 of Set 13 | trelew
# Processing Record 25 of Set 13 | tagusao
# Processing Record 26 of Set 13 | sudbury
# Processing Record 27 of Set 13 | luoyang
# Processing Record 28 of Set 13 | gusinoye ozero
# Processing Record 29 of Set 13 | hualmay
# Processing Record 30 of Set 13 | falam
# Processing Record 31 of Set 13 | wagar
# Processing Record 32 of Set 13 | paamiut
# Processing Record 33 of Set 13 | gushikawa
# Processing Record 34 of Set 13 | aitape
# Processing Record 35 of Set 13 | curvelo
# Processing Record 36 of Set 13 | gat
# Processing Record 37 of Set 13 | dunedin
# Processing Record 38 of Set 13 | soe
# Processing Record 39 of Set 13 | drabiv
# Processing Record 40 of Set 13 | the valley
# Processing Record 41 of Set 13 | vanimo
# Processing Record 42 of Set 13 | umm lajj
# Processing Record 43 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 44 of Set 13 | sistranda
# Processing Record 45 of Set 13 | eirunepe
# Processing Record 46 of Set 13 | iwanai
# Processing Record 47 of Set 13 | libenge
# Processing Record 48 of Set 13 | kahta
# Processing Record 49 of Set 13 | dingle
# Processing Record 50 of Set 13 | barinas
# Processing Record 1 of Set 14 | phillaur
# Processing Record 2 of Set 14 | tjaereborg
# Processing Record 3 of Set 14 | zhuhai
# Processing Record 4 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 5 of Set 14 | portoferraio
# Processing Record 6 of Set 14 | leh
# Processing Record 7 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | kampong thum
# Processing Record 9 of Set 14 | beroroha
# Processing Record 10 of Set 14 | maridi
# Processing Record 11 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 12 of Set 14 | savannakhet
# Processing Record 13 of Set 14 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 14 of Set 14 | port keats
# Processing Record 15 of Set 14 | tiznit
# Processing Record 16 of Set 14 | pacifica
# Processing Record 17 of Set 14 | ouargaye
# Processing Record 18 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 14 | caravelas
# Processing Record 20 of Set 14 | turukhansk
# Processing Record 21 of Set 14 | barreirinha
# Processing Record 22 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | maputo
# Processing Record 24 of Set 14 | camana
# Processing Record 25 of Set 14 | ancud
# Processing Record 26 of Set 14 | manglaur
# Processing Record 27 of Set 14 | plettenberg bay
# Processing Record 28 of Set 14 | arrifes
# Processing Record 29 of Set 14 | baoying
# Processing Record 30 of Set 14 | bolivar
# Processing Record 31 of Set 14 | chipinge
# Processing Record 32 of Set 14 | alice springs
# Processing Record 33 of Set 14 | presidencia roque saenz pena
# Processing Record 34 of Set 14 | da nang
# Processing Record 35 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 14 | priladozhskiy
# Processing Record 37 of Set 14 | chapais
# Processing Record 38 of Set 14 | penarroya-pueblonuevo
# Processing Record 39 of Set 14 | bobrov
# Processing Record 40 of Set 14 | shelburne
# Processing Record 41 of Set 14 | sembe
# Processing Record 42 of Set 14 | ilyich
# Processing Record 43 of Set 14 | trairi
# Processing Record 44 of Set 14 | champerico
# Processing Record 45 of Set 14 | padang
# Processing Record 46 of Set 14 | payo
# Processing Record 47 of Set 14 | tuatapere
# Processing Record 48 of Set 14 | skala
# Processing Record 49 of Set 14 | awbari
# Processing Record 50 of Set 14 | kosonsoy
# Processing Record 1 of Set 15 | la rinconada
# Processing Record 2 of Set 15 | barvinkove
# Processing Record 3 of Set 15 | san juan
# Processing Record 4 of Set 15 | olot
# Processing Record 5 of Set 15 | reinosa
# Processing Record 6 of Set 15 | port blair
# Processing Record 7 of Set 15 | patitirion
# Processing Record 8 of Set 15 | xining
# Processing Record 9 of Set 15 | herat
# Processing Record 10 of Set 15 | kankan
# Processing Record 11 of Set 15 | shambu
# Processing Record 12 of Set 15 | solnechnogorsk
# Processing Record 13 of Set 15 | wuwei
# Processing Record 14 of Set 15 | comodoro rivadavia
# Processing Record 15 of Set 15 | gulu
# Processing Record 16 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | meadow lake
# Processing Record 18 of Set 15 | laguna
# Processing Record 19 of Set 15 | tura
# Processing Record 20 of Set 15 | yining
# Processing Record 21 of Set 15 | rudbar
# Processing Record 22 of Set 15 | shumskiy
# Processing Record 23 of Set 15 | wanaka
# Processing Record 24 of Set 15 | adeje
# Processing Record 25 of Set 15 | mindif
# Processing Record 26 of Set 15 | teknaf
# Processing Record 27 of Set 15 | tambacounda
# Processing Record 28 of Set 15 | makakilo city
# Processing Record 29 of Set 15 | mulchen
# Processing Record 30 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 15 | mishelevka
# Processing Record 33 of Set 15 | hirara
# Processing Record 34 of Set 15 | mogadishu
# Processing Record 35 of Set 15 | markova
# Processing Record 36 of Set 15 | wanning
# Processing Record 37 of Set 15 | katima mulilo
# Processing Record 38 of Set 15 | batouri
# Processing Record 39 of Set 15 | humen
# Processing Record 40 of Set 15 | popondetta
# Processing Record 41 of Set 15 | pangkalanbuun
# Processing Record 42 of Set 15 | smithers
# Processing Record 43 of Set 15 | liverpool
# Processing Record 44 of Set 15 | kupang
# Processing Record 45 of Set 15 | bandiagara
# Processing Record 46 of Set 15 | namatanai
# Processing Record 47 of Set 15 | huangchuan
# Processing Record 48 of Set 15 | tyumentsevo
# Processing Record 49 of Set 15 | kawalu
# Processing Record 50 of Set 15 | kajaani
# Processing Record 1 of Set 16 | la palma
# Processing Record 2 of Set 16 | moba
# Processing Record 3 of Set 16 | peniche
# Processing Record 4 of Set 16 | pathein
# Processing Record 5 of Set 16 | bilyayivka
# Processing Record 6 of Set 16 | lavrentiya
# Processing Record 7 of Set 16 | kichera
# Processing Record 8 of Set 16 | tres arroyos
# Processing Record 9 of Set 16 | cochrane
# Processing Record 10 of Set 16 | tena
# Processing Record 11 of Set 16 | bayan
# Processing Record 12 of Set 16 | pombas
# Processing Record 13 of Set 16 | talakan
# Processing Record 14 of Set 16 | anchorage
# Processing Record 15 of Set 16 | contai
# Processing Record 16 of Set 16 | galchino
# City not found. Skipping...
# Processing Record 17 of Set 16 | manthani
# Processing Record 18 of Set 16 | griffith
# Processing Record 19 of Set 16 | port-gentil
# Processing Record 20 of Set 16 | naspur
# Processing Record 21 of Set 16 | samana
# Processing Record 22 of Set 16 | uyuni
# Processing Record 23 of Set 16 | sept-iles
# Processing Record 24 of Set 16 | velyka pysarivka
# Processing Record 25 of Set 16 | north platte
# Processing Record 26 of Set 16 | peace river
# Processing Record 27 of Set 16 | riverton
# Processing Record 28 of Set 16 | hastinapur
# Processing Record 29 of Set 16 | caramay
# Processing Record 30 of Set 16 | ust-donetskiy
# Processing Record 31 of Set 16 | samagaltay
# Processing Record 32 of Set 16 | seoul
# Processing Record 33 of Set 16 | port shepstone
# Processing Record 34 of Set 16 | linkoping
# Processing Record 35 of Set 16 | nantucket
# Processing Record 36 of Set 16 | harper
# Processing Record 37 of Set 16 | nabire
# Processing Record 38 of Set 16 | nortelandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Thompson  55.7435  -97.8558     73.56        33          40
# 1      Concepcion -36.8270  -73.0498     51.60        62         100
# 2          Atuona  -9.8000 -139.0333     76.80        81          29
# 3         Bushehr  28.9684   50.8385     91.15        62           0
# 4       Jamestown  42.0970  -79.2353     70.02        74         100
# 5       Busselton -33.6500  115.3333     47.44        84          83
# 6  Severo-Kurilsk  50.6789  156.1250     57.11        92         100
# 7         Mataura -46.1927  168.8643     44.47        92          95
# 8         Qaanaaq  77.4840  -69.3632     33.49        83          80
# 9       Omsukchan  62.5333  155.8000     40.03        91         100
#
#    Wind Speed Country Current Description
# 0       11.50      CA    scattered clouds
# 1       14.97      CL     overcast clouds
# 2       28.16      PF          light rain
# 3        0.92      IR           clear sky
# 4       10.36      US     overcast clouds
# 5        5.46      AU       broken clouds
# 6       17.74      RU          light rain
# 7        1.92      NZ     overcast clouds
# 8        1.39      GL       broken clouds
# 9        6.69      RU     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
