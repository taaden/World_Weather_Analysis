# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description =city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | buraydah
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | mikuni
# Processing Record 7 of Set 1 | baghdad
# Processing Record 8 of Set 1 | millinocket
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | leh
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | kieta
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | ust-kuyga
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | jalu
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | gizo
# Processing Record 25 of Set 1 | svetlogorsk
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | shar
# Processing Record 28 of Set 1 | ormara
# Processing Record 29 of Set 1 | marang
# Processing Record 30 of Set 1 | koumac
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | merauke
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | rawson
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | ko samui
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | yuli
# Processing Record 41 of Set 1 | noshiro
# Processing Record 42 of Set 1 | los llanos de aridane
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 45 of Set 1 | arbazh
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | behshahr
# Processing Record 48 of Set 1 | porto walter
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | san jose
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | sambava
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 2 | lorengau
# Processing Record 8 of Set 2 | yelizavetinskoye
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | chuchkovo
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | merke
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | alghero
# Processing Record 17 of Set 2 | jackson
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | popondetta
# Processing Record 20 of Set 2 | ocala
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | krasnoselkup
# Processing Record 23 of Set 2 | paamiut
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | saint-augustin
# Processing Record 27 of Set 2 | vitim
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | gummidipundi
# Processing Record 30 of Set 2 | bezhetsk
# Processing Record 31 of Set 2 | port augusta
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | colesberg
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | kaniama
# Processing Record 37 of Set 2 | maceio
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | hualmay
# Processing Record 40 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | rapar
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | shingu
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | saint-joseph
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | salta
# Processing Record 2 of Set 3 | waihi
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | marsh harbour
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | nhamunda
# Processing Record 8 of Set 3 | komsomolskiy
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | guadalupe y calvo
# Processing Record 11 of Set 3 | the valley
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | sarh
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | dunshaughlin
# Processing Record 18 of Set 3 | belmonte
# Processing Record 19 of Set 3 | puerto narino
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | humaita
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | eydhafushi
# Processing Record 28 of Set 3 | bafq
# Processing Record 29 of Set 3 | port hardy
# Processing Record 30 of Set 3 | zorritos
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | kiama
# Processing Record 33 of Set 3 | omboue
# Processing Record 34 of Set 3 | verkhoyansk
# Processing Record 35 of Set 3 | miramar
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | guane
# Processing Record 39 of Set 3 | chateaubelair
# Processing Record 40 of Set 3 | sangar
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | bonavista
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | georgetown
# Processing Record 45 of Set 3 | abaza
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | qaanaaq
# Processing Record 48 of Set 3 | kasongo-lunda
# Processing Record 49 of Set 3 | oranjestad
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | darnah
# Processing Record 2 of Set 4 | abomsa
# Processing Record 3 of Set 4 | pascagoula
# Processing Record 4 of Set 4 | kamenka
# Processing Record 5 of Set 4 | tura
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | talakan
# Processing Record 9 of Set 4 | namatanai
# Processing Record 10 of Set 4 | malanje
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | aktash
# Processing Record 13 of Set 4 | big rapids
# Processing Record 14 of Set 4 | meylan
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | castro
# Processing Record 17 of Set 4 | santiago del estero
# Processing Record 18 of Set 4 | nusaybin
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | mookane
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | flinders
# Processing Record 24 of Set 4 | port-gentil
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | fonte boa
# Processing Record 27 of Set 4 | bakel
# Processing Record 28 of Set 4 | praxedis guerrero
# Processing Record 29 of Set 4 | sorland
# Processing Record 30 of Set 4 | makakilo city
# Processing Record 31 of Set 4 | amalapuram
# Processing Record 32 of Set 4 | sai buri
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | panguna
# Processing Record 35 of Set 4 | port elizabeth
# Processing Record 36 of Set 4 | ventanas
# Processing Record 37 of Set 4 | roanoke rapids
# Processing Record 38 of Set 4 | preston
# Processing Record 39 of Set 4 | maragogi
# Processing Record 40 of Set 4 | sumenep
# Processing Record 41 of Set 4 | tessalit
# Processing Record 42 of Set 4 | bayji
# Processing Record 43 of Set 4 | sioux lookout
# Processing Record 44 of Set 4 | canon city
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | asyut
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | faya
# Processing Record 49 of Set 4 | north bend
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | chapais
# Processing Record 3 of Set 5 | bintulu
# Processing Record 4 of Set 5 | assiniboia
# Processing Record 5 of Set 5 | poggibonsi
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | idar
# Processing Record 8 of Set 5 | de haan
# Processing Record 9 of Set 5 | uglekamensk
# Processing Record 10 of Set 5 | revda
# Processing Record 11 of Set 5 | vizinga
# Processing Record 12 of Set 5 | vaini
# Processing Record 13 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 5 | gamba
# Processing Record 16 of Set 5 | normandin
# Processing Record 17 of Set 5 | atlantis
# Processing Record 18 of Set 5 | rawah
# Processing Record 19 of Set 5 | okhotsk
# Processing Record 20 of Set 5 | padang
# Processing Record 21 of Set 5 | silver city
# Processing Record 22 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 5 | saint george
# Processing Record 25 of Set 5 | baft
# Processing Record 26 of Set 5 | pacific grove
# Processing Record 27 of Set 5 | whyalla
# Processing Record 28 of Set 5 | houma
# Processing Record 29 of Set 5 | ust-uda
# Processing Record 30 of Set 5 | portland
# Processing Record 31 of Set 5 | santa lucia
# Processing Record 32 of Set 5 | tuy hoa
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | nome
# Processing Record 35 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 5 | sinnamary
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 5 | kruisfontein
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | huescar
# Processing Record 42 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 5 | inuvik
# Processing Record 44 of Set 5 | marzuq
# Processing Record 45 of Set 5 | bud
# Processing Record 46 of Set 5 | rongu
# City not found. Skipping...
# Processing Record 47 of Set 5 | ambilobe
# Processing Record 48 of Set 5 | san antonio
# Processing Record 49 of Set 5 | ixtapa
# Processing Record 50 of Set 5 | bandarbeyla
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | antofagasta
# Processing Record 3 of Set 6 | zharkent
# Processing Record 4 of Set 6 | nantucket
# Processing Record 5 of Set 6 | kununurra
# Processing Record 6 of Set 6 | belem
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | mittagong
# Processing Record 9 of Set 6 | george
# Processing Record 10 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | oriximina
# Processing Record 14 of Set 6 | nouadhibou
# Processing Record 15 of Set 6 | san francisco
# Processing Record 16 of Set 6 | krasnorechenskiy
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | dengzhou
# Processing Record 19 of Set 6 | piacabucu
# Processing Record 20 of Set 6 | indramayu
# Processing Record 21 of Set 6 | oranjemund
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | matara
# Processing Record 24 of Set 6 | aljezur
# Processing Record 25 of Set 6 | namikupa
# Processing Record 26 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 6 | dembi dolo
# Processing Record 30 of Set 6 | tual
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | alta floresta
# Processing Record 33 of Set 6 | chenghai
# Processing Record 34 of Set 6 | coahuayana
# Processing Record 35 of Set 6 | sabang
# Processing Record 36 of Set 6 | czluchow
# Processing Record 37 of Set 6 | balakhta
# Processing Record 38 of Set 6 | san juan
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | uchiza
# Processing Record 41 of Set 6 | kolyvan
# Processing Record 42 of Set 6 | yangambi
# Processing Record 43 of Set 6 | ribas do rio pardo
# Processing Record 44 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 6 | nhulunbuy
# Processing Record 46 of Set 6 | aksarka
# Processing Record 47 of Set 6 | khandyga
# Processing Record 48 of Set 6 | saint-leu
# Processing Record 49 of Set 6 | sibolga
# Processing Record 50 of Set 6 | jimeta
# Processing Record 1 of Set 7 | lalmohan
# Processing Record 2 of Set 7 | talara
# Processing Record 3 of Set 7 | gillette
# Processing Record 4 of Set 7 | vestmanna
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | iralaya
# Processing Record 7 of Set 7 | pitimbu
# Processing Record 8 of Set 7 | humberto de campos
# Processing Record 9 of Set 7 | san luis
# Processing Record 10 of Set 7 | halifax
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | baykit
# Processing Record 13 of Set 7 | poum
# Processing Record 14 of Set 7 | rondonopolis
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | vilhena
# Processing Record 17 of Set 7 | souillac
# Processing Record 18 of Set 7 | clinton
# Processing Record 19 of Set 7 | howard springs
# Processing Record 20 of Set 7 | valparaiso
# Processing Record 21 of Set 7 | daru
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | zyryanka
# Processing Record 25 of Set 7 | golkoy
# Processing Record 26 of Set 7 | bernal
# Processing Record 27 of Set 7 | bulancak
# Processing Record 28 of Set 7 | sines
# Processing Record 29 of Set 7 | sept-iles
# Processing Record 30 of Set 7 | ozieri
# Processing Record 31 of Set 7 | los alamos
# Processing Record 32 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 7 | saint-pierre
# Processing Record 34 of Set 7 | miri
# Processing Record 35 of Set 7 | alofi
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | aitape
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | morros
# Processing Record 40 of Set 7 | upleta
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | kahului
# Processing Record 43 of Set 7 | saint anthony
# Processing Record 44 of Set 7 | costinesti
# Processing Record 45 of Set 7 | ahmadpur east
# Processing Record 46 of Set 7 | ballesteros
# Processing Record 47 of Set 7 | ryotsu
# Processing Record 48 of Set 7 | izhma
# Processing Record 49 of Set 7 | birjand
# Processing Record 50 of Set 7 | kropotkin
# Processing Record 1 of Set 8 | middelburg
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | champerico
# Processing Record 4 of Set 8 | sistranda
# Processing Record 5 of Set 8 | santa cruz
# Processing Record 6 of Set 8 | aswan
# Processing Record 7 of Set 8 | muzhi
# Processing Record 8 of Set 8 | north platte
# Processing Record 9 of Set 8 | debre birhan
# Processing Record 10 of Set 8 | esperance
# Processing Record 11 of Set 8 | piripiri
# Processing Record 12 of Set 8 | peniche
# Processing Record 13 of Set 8 | eyl
# Processing Record 14 of Set 8 | sakakah
# Processing Record 15 of Set 8 | zavetnoye
# Processing Record 16 of Set 8 | dunmore town
# Processing Record 17 of Set 8 | yaan
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | ardakan
# Processing Record 20 of Set 8 | wad rawah
# Processing Record 21 of Set 8 | emirdag
# Processing Record 22 of Set 8 | kabanjahe
# Processing Record 23 of Set 8 | karpathos
# Processing Record 24 of Set 8 | mehamn
# Processing Record 25 of Set 8 | guimbal
# Processing Record 26 of Set 8 | saint-francois
# Processing Record 27 of Set 8 | kavaratti
# Processing Record 28 of Set 8 | puerto leguizamo
# Processing Record 29 of Set 8 | wad madani
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | lishu
# Processing Record 32 of Set 8 | vardo
# Processing Record 33 of Set 8 | itamarandiba
# Processing Record 34 of Set 8 | cianorte
# Processing Record 35 of Set 8 | ribeira grande
# Processing Record 36 of Set 8 | lebyazhye
# Processing Record 37 of Set 8 | havelock
# Processing Record 38 of Set 8 | wanning
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | doha
# Processing Record 41 of Set 8 | antalaha
# Processing Record 42 of Set 8 | necochea
# Processing Record 43 of Set 8 | cody
# Processing Record 44 of Set 8 | panama city
# Processing Record 45 of Set 8 | kigoma
# Processing Record 46 of Set 8 | ningbo
# Processing Record 47 of Set 8 | sao gabriel da cachoeira
# Processing Record 48 of Set 8 | geraldton
# Processing Record 49 of Set 8 | novikovo
# Processing Record 50 of Set 8 | carpenedolo
# Processing Record 1 of Set 9 | emerald
# Processing Record 2 of Set 9 | davila
# Processing Record 3 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 9 | hay river
# Processing Record 5 of Set 9 | banjar
# Processing Record 6 of Set 9 | mendi
# Processing Record 7 of Set 9 | kapitanivka
# Processing Record 8 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | wewak
# Processing Record 12 of Set 9 | candawaga
# City not found. Skipping...
# Processing Record 13 of Set 9 | noumea
# Processing Record 14 of Set 9 | iqaluit
# Processing Record 15 of Set 9 | ayorou
# Processing Record 16 of Set 9 | kroya
# Processing Record 17 of Set 9 | vestmannaeyjar
# Processing Record 18 of Set 9 | tateyama
# Processing Record 19 of Set 9 | havre-saint-pierre
# Processing Record 20 of Set 9 | les cayes
# Processing Record 21 of Set 9 | liku
# Processing Record 22 of Set 9 | tamworth
# Processing Record 23 of Set 9 | bassila
# Processing Record 24 of Set 9 | akdepe
# Processing Record 25 of Set 9 | la sarre
# Processing Record 26 of Set 9 | bilibino
# Processing Record 27 of Set 9 | ukiah
# Processing Record 28 of Set 9 | tahe
# Processing Record 29 of Set 9 | karoi
# Processing Record 30 of Set 9 | anadyr
# Processing Record 31 of Set 9 | piura
# Processing Record 32 of Set 9 | mandalgovi
# Processing Record 33 of Set 9 | corinto
# Processing Record 34 of Set 9 | gornyy
# Processing Record 35 of Set 9 | chicama
# Processing Record 36 of Set 9 | winchester
# Processing Record 37 of Set 9 | gorom-gorom
# Processing Record 38 of Set 9 | muli
# Processing Record 39 of Set 9 | darovskoy
# Processing Record 40 of Set 9 | grand gaube
# Processing Record 41 of Set 9 | helong
# Processing Record 42 of Set 9 | acari
# Processing Record 43 of Set 9 | cabinda
# Processing Record 44 of Set 9 | partur
# Processing Record 45 of Set 9 | gondanglegi
# Processing Record 46 of Set 9 | mecca
# Processing Record 47 of Set 9 | fort nelson
# Processing Record 48 of Set 9 | sao francisco do sul
# Processing Record 49 of Set 9 | tommot
# Processing Record 50 of Set 9 | abu samrah
# Processing Record 1 of Set 10 | meulaboh
# Processing Record 2 of Set 10 | yumen
# Processing Record 3 of Set 10 | susanville
# Processing Record 4 of Set 10 | kangaatsiaq
# Processing Record 5 of Set 10 | udachnyy
# Processing Record 6 of Set 10 | skjervoy
# Processing Record 7 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | manado
# Processing Record 9 of Set 10 | egvekinot
# Processing Record 10 of Set 10 | monrovia
# Processing Record 11 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 12 of Set 10 | roald
# Processing Record 13 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 14 of Set 10 | srednekolymsk
# Processing Record 15 of Set 10 | luderitz
# Processing Record 16 of Set 10 | sekoma
# Processing Record 17 of Set 10 | inzhavino
# Processing Record 18 of Set 10 | notre-dame-du-lac
# Processing Record 19 of Set 10 | kirakira
# Processing Record 20 of Set 10 | sao jose da coroa grande
# Processing Record 21 of Set 10 | hamilton
# Processing Record 22 of Set 10 | narsaq
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | biala podlaska
# Processing Record 25 of Set 10 | lexington
# Processing Record 26 of Set 10 | mount pleasant
# Processing Record 27 of Set 10 | pueblo rico
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 30 of Set 10 | frei paulo
# Processing Record 31 of Set 10 | rosita
# Processing Record 32 of Set 10 | jacqueville
# Processing Record 33 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 34 of Set 10 | palmer
# Processing Record 35 of Set 10 | madaoua
# Processing Record 36 of Set 10 | kundla
# Processing Record 37 of Set 10 | christchurch
# Processing Record 38 of Set 10 | caravelas
# Processing Record 39 of Set 10 | diffa
# Processing Record 40 of Set 10 | margate
# Processing Record 41 of Set 10 | treinta y tres
# Processing Record 42 of Set 10 | ban nahin
# Processing Record 43 of Set 10 | pipar
# Processing Record 44 of Set 10 | claye-souilly
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | buala
# Processing Record 47 of Set 10 | sao joao da barra
# Processing Record 48 of Set 10 | cervo
# Processing Record 49 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 50 of Set 10 | beringovskiy
# Processing Record 1 of Set 11 | rongcheng
# Processing Record 2 of Set 11 | bara
# Processing Record 3 of Set 11 | zhenhai
# Processing Record 4 of Set 11 | xichang
# Processing Record 5 of Set 11 | imbituba
# Processing Record 6 of Set 11 | shahrud
# Processing Record 7 of Set 11 | iquitos
# Processing Record 8 of Set 11 | mgandu
# Processing Record 9 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 11 | illapel
# Processing Record 11 of Set 11 | naze
# Processing Record 12 of Set 11 | bayonet point
# Processing Record 13 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | clyde river
# Processing Record 16 of Set 11 | awbari
# Processing Record 17 of Set 11 | mamallapuram
# Processing Record 18 of Set 11 | mapiripan
# Processing Record 19 of Set 11 | parsons
# Processing Record 20 of Set 11 | bosobolo
# Processing Record 21 of Set 11 | iskateley
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 11 | kutum
# Processing Record 25 of Set 11 | babaeski
# Processing Record 26 of Set 11 | belyy yar
# Processing Record 27 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 11 | lastoursville
# Processing Record 29 of Set 11 | amursk
# Processing Record 30 of Set 11 | nizhneudinsk
# Processing Record 31 of Set 11 | broken hill
# Processing Record 32 of Set 11 | kamyshin
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | vershino-darasunskiy
# Processing Record 35 of Set 11 | cocobeach
# Processing Record 36 of Set 11 | zlate moravce
# Processing Record 37 of Set 11 | ambon
# Processing Record 38 of Set 11 | fomboni
# Processing Record 39 of Set 11 | warangal
# Processing Record 40 of Set 11 | vila franca do campo
# Processing Record 41 of Set 11 | nylstroom
# City not found. Skipping...
# Processing Record 42 of Set 11 | verkhnebakanskiy
# Processing Record 43 of Set 11 | pipri
# Processing Record 44 of Set 11 | sovetskoye
# Processing Record 45 of Set 11 | xuanhua
# Processing Record 46 of Set 11 | tazmalt
# Processing Record 47 of Set 11 | vangaindrano
# Processing Record 48 of Set 11 | henties bay
# Processing Record 49 of Set 11 | tadine
# Processing Record 50 of Set 11 | samarinda
# Processing Record 1 of Set 12 | hai phong
# City not found. Skipping...
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | taos
# Processing Record 4 of Set 12 | nemuro
# Processing Record 5 of Set 12 | itapema
# Processing Record 6 of Set 12 | conceicao do araguaia
# Processing Record 7 of Set 12 | handan
# Processing Record 8 of Set 12 | port blair
# Processing Record 9 of Set 12 | tobermory
# Processing Record 10 of Set 12 | tsumeb
# Processing Record 11 of Set 12 | abhar
# Processing Record 12 of Set 12 | south venice
# Processing Record 13 of Set 12 | cayenne
# Processing Record 14 of Set 12 | cockburn town
# Processing Record 15 of Set 12 | hasaki
# Processing Record 16 of Set 12 | yelniki
# Processing Record 17 of Set 12 | gold coast
# Processing Record 18 of Set 12 | dingle
# Processing Record 19 of Set 12 | ostrovnoy
# Processing Record 20 of Set 12 | bundaberg
# Processing Record 21 of Set 12 | cravo norte
# Processing Record 22 of Set 12 | burica
# City not found. Skipping...
# Processing Record 23 of Set 12 | stornoway
# Processing Record 24 of Set 12 | payson
# Processing Record 25 of Set 12 | tatawin
# Processing Record 26 of Set 12 | bambous virieux
# Processing Record 27 of Set 12 | mao
# Processing Record 28 of Set 12 | san blas
# Processing Record 29 of Set 12 | gorontalo
# Processing Record 30 of Set 12 | fremont
# Processing Record 31 of Set 12 | ojinaga
# Processing Record 32 of Set 12 | milkovo
# Processing Record 33 of Set 12 | green valley
# Processing Record 34 of Set 12 | lincoln
# Processing Record 35 of Set 12 | sopiste
# City not found. Skipping...
# Processing Record 36 of Set 12 | kismayo
# Processing Record 37 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 12 | katobu
# Processing Record 39 of Set 12 | cochrane
# Processing Record 40 of Set 12 | lavrentiya
# Processing Record 41 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 42 of Set 12 | rockport
# Processing Record 43 of Set 12 | porto velho
# Processing Record 44 of Set 12 | xapuri
# Processing Record 45 of Set 12 | hervey bay
# Processing Record 46 of Set 12 | sur
# Processing Record 47 of Set 12 | ishinomaki
# Processing Record 48 of Set 12 | verkhnyaya inta
# Processing Record 49 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 12 | sawtell
# Processing Record 1 of Set 13 | broome
# Processing Record 2 of Set 13 | vengurla
# Processing Record 3 of Set 13 | sol-iletsk
# Processing Record 4 of Set 13 | bend
# Processing Record 5 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 6 of Set 13 | beisfjord
# Processing Record 7 of Set 13 | digby
# Processing Record 8 of Set 13 | mizdah
# Processing Record 9 of Set 13 | manokwari
# Processing Record 10 of Set 13 | wasilla
# Processing Record 11 of Set 13 | carai
# Processing Record 12 of Set 13 | fortuna
# Processing Record 13 of Set 13 | chuguyevka
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | talcahuano
# Processing Record 16 of Set 13 | bathsheba
# Processing Record 17 of Set 13 | puerto del rosario
# Processing Record 18 of Set 13 | samarai
# Processing Record 19 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 13 | roma
# Processing Record 21 of Set 13 | hauterive
# Processing Record 22 of Set 13 | waddan
# Processing Record 23 of Set 13 | prince rupert
# Processing Record 24 of Set 13 | sinegorye
# Processing Record 25 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | acapulco
# Processing Record 27 of Set 13 | sint michiel
# City not found. Skipping...
# Processing Record 28 of Set 13 | oxelosund
# Processing Record 29 of Set 13 | kambove
# Processing Record 30 of Set 13 | duz
# City not found. Skipping...
# Processing Record 31 of Set 13 | arroio grande
# Processing Record 32 of Set 13 | baruun-urt
# Processing Record 33 of Set 13 | totness
# Processing Record 34 of Set 13 | tigil
# Processing Record 35 of Set 13 | flin flon
# Processing Record 36 of Set 13 | taylorville
# Processing Record 37 of Set 13 | san cristobal
# Processing Record 38 of Set 13 | fulacunda
# City not found. Skipping...
# Processing Record 39 of Set 13 | lima
# Processing Record 40 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 13 | pahalgam
# Processing Record 42 of Set 13 | chiredzi
# Processing Record 43 of Set 13 | ashland
# Processing Record 44 of Set 13 | arlit
# Processing Record 45 of Set 13 | nizwa
# Processing Record 46 of Set 13 | el wasta
# City not found. Skipping...
# Processing Record 47 of Set 13 | kayerkan
# Processing Record 48 of Set 13 | kiunga
# Processing Record 49 of Set 13 | te anau
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | shache
# Processing Record 2 of Set 14 | takoradi
# Processing Record 3 of Set 14 | devonport
# Processing Record 4 of Set 14 | watsa
# Processing Record 5 of Set 14 | cairns
# Processing Record 6 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 14 | hovd
# Processing Record 8 of Set 14 | patea
# Processing Record 9 of Set 14 | dera bugti
# Processing Record 10 of Set 14 | carbondale
# Processing Record 11 of Set 14 | rehoboth
# Processing Record 12 of Set 14 | smolenka
# Processing Record 13 of Set 14 | bitung
# Processing Record 14 of Set 14 | moron
# Processing Record 15 of Set 14 | kaitangata
# Processing Record 16 of Set 14 | vao
# Processing Record 17 of Set 14 | wichita
# Processing Record 18 of Set 14 | bowen
# Processing Record 19 of Set 14 | takaka
# Processing Record 20 of Set 14 | norrtalje
# Processing Record 21 of Set 14 | aykhal
# Processing Record 22 of Set 14 | agadir
# Processing Record 23 of Set 14 | altay
# Processing Record 24 of Set 14 | kongolo
# Processing Record 25 of Set 14 | maningrida
# Processing Record 26 of Set 14 | morgan city
# Processing Record 27 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 14 | korla
# Processing Record 29 of Set 14 | hede
# Processing Record 30 of Set 14 | filadelfia
# Processing Record 31 of Set 14 | bubaque
# Processing Record 32 of Set 14 | juegang
# Processing Record 33 of Set 14 | coolum beach
# Processing Record 34 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 14 | opuwo
# Processing Record 36 of Set 14 | olafsvik
# Processing Record 37 of Set 14 | hanzhong
# Processing Record 38 of Set 14 | hainburg
# Processing Record 39 of Set 14 | ust-nera
# Processing Record 40 of Set 14 | manadhoo
# Processing Record 41 of Set 14 | sakaiminato
# Processing Record 42 of Set 14 | carpinteria
# Processing Record 43 of Set 14 | great yarmouth
# Processing Record 44 of Set 14 | sesheke
# Processing Record 45 of Set 14 | raymondville
# Processing Record 46 of Set 14 | ahipara
# Processing Record 47 of Set 14 | roncesvalles
# Processing Record 48 of Set 14 | verkhniy lomov
# Processing Record 49 of Set 14 | rutana
# Processing Record 50 of Set 14 | mogadishu
# Processing Record 1 of Set 15 | kanniyakumari
# Processing Record 2 of Set 15 | husavik
# Processing Record 3 of Set 15 | palafrugell
# Processing Record 4 of Set 15 | ca mau
# Processing Record 5 of Set 15 | deputatskiy
# Processing Record 6 of Set 15 | zacualpan
# Processing Record 7 of Set 15 | tautira
# Processing Record 8 of Set 15 | hecun
# Processing Record 9 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 15 | sitio novo do tocantins
# Processing Record 11 of Set 15 | lucapa
# Processing Record 12 of Set 15 | afsin
# Processing Record 13 of Set 15 | newport
# Processing Record 14 of Set 15 | lormont
# Processing Record 15 of Set 15 | urumqi
# Processing Record 16 of Set 15 | westport
# Processing Record 17 of Set 15 | liverpool
# Processing Record 18 of Set 15 | bialystok
# Processing Record 19 of Set 15 | roshchino
# Processing Record 20 of Set 15 | altar
# Processing Record 21 of Set 15 | beruwala
# Processing Record 22 of Set 15 | lazaro cardenas
# Processing Record 23 of Set 15 | lisakovsk
# Processing Record 24 of Set 15 | evensk
# Processing Record 25 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 26 of Set 15 | busca
# Processing Record 27 of Set 15 | gujrat
# Processing Record 28 of Set 15 | oudtshoorn
# Processing Record 29 of Set 15 | bay roberts
# Processing Record 30 of Set 15 | zhigansk
# Processing Record 31 of Set 15 | conroe
# Processing Record 32 of Set 15 | nyuksenitsa
# Processing Record 33 of Set 15 | ibra
# Processing Record 34 of Set 15 | romitan
# Processing Record 35 of Set 15 | vikindu
# Processing Record 36 of Set 15 | pangnirtung
# Processing Record 37 of Set 15 | basmat
# Processing Record 38 of Set 15 | mayo
# Processing Record 39 of Set 15 | bontang
# Processing Record 40 of Set 15 | thames
# Processing Record 41 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 15 | bougouni
# Processing Record 43 of Set 15 | kulhudhuffushi
# Processing Record 44 of Set 15 | wanaka
# Processing Record 45 of Set 15 | paulo afonso
# Processing Record 46 of Set 15 | kafanchan
# Processing Record 47 of Set 15 | martapura
# Processing Record 48 of Set 15 | hami
# Processing Record 49 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 15 | the pas
# Processing Record 1 of Set 16 | luancheng
# Processing Record 2 of Set 16 | sidi ali
# Processing Record 3 of Set 16 | boulder city
# Processing Record 4 of Set 16 | phulabani
# Processing Record 5 of Set 16 | kathu
# Processing Record 6 of Set 16 | rosamorada
# Processing Record 7 of Set 16 | bosaso
# Processing Record 8 of Set 16 | columbus
# Processing Record 9 of Set 16 | umm lajj
# Processing Record 10 of Set 16 | napoleon
# Processing Record 11 of Set 16 | mandurah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown  42.0970  -79.2353     75.06        46          75
# 1      Buraydah  26.3260   43.9750     96.17         9           0
# 2       Ushuaia -54.8000  -68.3000     39.42        80          99
# 3  Puerto Ayora  -0.7393  -90.3518     69.55        90         100
# 4        Mikuni  36.2171  136.1519     73.20        94          99
# 5       Baghdad  33.3406   44.4009     99.45        18           0
# 6   Millinocket  45.6573  -68.7098     72.41        64          20
# 7          Atar  20.5169  -13.0499    103.03        21           4
# 8    Butaritari   3.0707  172.7902     81.63        67          72
# 9           Leh  34.1667   77.5833     61.75        46          53
#
#    Wind Speed Country Current Description
# 0        1.01      US       broken clouds
# 1        8.25      SA           clear sky
# 2        5.95      AR     overcast clouds
# 3       11.01      EC     overcast clouds
# 4        7.70      JP     overcast clouds
# 5       12.75      IQ           clear sky
# 6        4.61      US          few clouds
# 7       12.01      MR           clear sky
# 8       14.92      KI       broken clouds
# 9        4.74      IN       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
